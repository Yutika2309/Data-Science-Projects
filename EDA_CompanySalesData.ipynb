# %% [markdown]
# **Name:** Yutika Rege
#
# **PRN:** 1901202012
#
# **DS303:** Machine Learning-1

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing and viewing the head of the dataset
df=pd.read_excel("company_sales_data.xlsx")
df.head(3).transpose()
# Out:
#                    0       1       2
# month_number       1       2       3
# facecream       2500    2630    2140
# facewash        1500    1200    1340
# toothpaste      5200    5100    4550
# bathingsoap     9200    6100    9550
# shampoo         1200    2100    3550
# moisturizer     1500    1200    1340
# total_units    21100   18330   22470
# total_profit  211000  183300  224700

# %% [markdown]
# **Q1. Read Total profit of all months and show it using a line plot.**

# %%
#although not necessary, the variables total_profit and month_number have been converted to lists
profit_list = df.total_profit.tolist()
month_list = df.month_number.tolist()

plt.plot(month_list,profit_list)

plt.title("Company profit per month")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")

plt.yticks([100000,200000,300000,400000,500000])
plt.xticks(month_list)

plt.figure(figsize=(10,7))
plt.show()

# %% [markdown]
# **Comment:-** It can be inferred from the plot above that the maximum profit of the company is seen in 11th month (presumably in November).

# %% [markdown]
# **Q2. Get Total profit of all months and show line plot with the following style properties.**
#
# Generated line plot must include following Style properties:–
#
# * Line Style dotted and Line-color should be red.
#
# * Show legend at the lower right location.
#
# * X label name = Month Number
#
# * Y label name = Sold units number
#
# * Add a circle marker.
#
# * Line marker color as red
#
# * Line width should be 3

# %%
#plotting the line plot on the basis of the above mentioned parameters 
plt.plot(month_list, profit_list, label = "Profit data of last year", color='r', marker='o', markerfacecolor='k', linestyle='--', linewidth=3)
      
plt.xlabel("Month Number")
plt.ylabel("Profit")
plt.legend(loc='lower right')

plt.title('Company Sales data of last year')
plt.xticks(month_list)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %% [markdown]
# **Q3. Read all product sales data and show it using a multiline plot.**

# %%
df.columns
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
#plotting all the items present in the dataset so as to compare their sales
plt.plot(month_list,df.facecream,label = "Facecream Sales Data", marker='o')
plt.plot(month_list,df.facewash ,label = "Facewash Sales Data", marker='o')
plt.plot(month_list,df.toothpaste,label = "Toothpaste Sales Data", marker='o')
plt.plot(month_list,df.bathingsoap,label = "Bathingsoap Sales Data", marker='o')
plt.plot(month_list,df.shampoo,label = "Shampoo Sales Data", marker='o')
plt.plot(month_list,df.moisturizer,label = "Moisturizer Sales Data", marker='o')

#adding titles to the axes and adding a legend
plt.title("Sales data")
plt.xlabel("Month Number")
plt.ylabel("Sales units in number")
plt.legend(loc = "upper left")

#setting a scale for the axes
plt.yticks([1000,2000,4000,8000,10000,12000,15000,18000])
plt.xticks(month_list)

plt.figure(figsize=(10,10))

plt.show()

# %% [markdown]
# **Comment:-** From the plot above, one can make out that the sales of _Bathing Soap_ in particular is higher as compared to the other products while the sales of _Moisturizer_ is the least. Overall, the trend of sales observes a positive trend throughout the year with a only a few plumets.

# %% [markdown]
# **Note:-** The plot below has been made separately owing to the fact that the trend for Facewash is close to invisible in the plot above.

# %%
#making an individual plot for Facewash data due its invisibility in the plot above

plt.title("Sales data")
plt.xlabel("Month Number")
plt.ylabel("Sales units in number")
plt.plot(month_list,df.facewash,marker='o',color="orange")
plt.title("Facewash Sales Data")
plt.xticks(month_list)
plt.yticks([1000,2000,4000,8000,10000,12000,15000,18000])

plt.figure(figsize=(10,10))

# %% [markdown]
# **Comment:-** The sales for _Facewash_ is at its peak in the 11th month and follows a sales trend akin to _Moisturizer_.Thus, it can be concluded that the least selling products of the company are _Moisturizer_ and _Facewash_.

# %% [markdown]
# **Q4. Read toothpaste sales data of each month and show it using a scatter plot. Also, add a grid in the plot. gridline style should be "–".**

# %%
plt.scatter(month_list,df.toothpaste,label="Tooth paste sales data")
plt.xticks(month_list)
plt.yticks([4500,5000,5500,6000,6500,7000,7500,8000])

plt.xlabel("Month Number")
plt.ylabel("Number of units sold")
plt.legend(loc='upper left')
plt.title("Tooth paste sales data")
plt.grid("True",ls="--")

plt.figure(figsize=(10,10))

plt.show()

# %% [markdown]
# **Comment:-** The maximum sales for toothpaste are seen in the 10th month (presumably - October).

# %% [markdown]
# **Q5. Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.**

# %%
plt.bar([size-0.25 for size in month_list],df.facecream,width= 0.25, label = "Face Cream sales data", align="edge")
plt.bar([size+0.25 for size in month_list],df.facewash,width= -0.25, label = "Face Wash sales data", align="edge")

plt.xlabel("Month Number")
plt.ylabel('Sales units in number')
plt.legend(loc="upper left")
plt.title("Sales Data")

plt.xticks(month_list)
plt.grid("True",ls="--")

plt.figure(figsize=(10,7))
plt.show()

# %% [markdown]
# **Comment:-** The sales of _Facewash_ in comparison to _Facecream_ is very less. _Facecream_ has maximum sale in month no. 8 (August) while _Facewash_ has maximum sales in month no. 11 (November).

# %% [markdown]
# **Q6. Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.**

# %%
plt.bar(month_list,df.bathingsoap)

plt.xlabel("Month Number")
plt.ylabel("Sales units in number")
plt.title("Sales data")
plt.xticks(month_list)

plt.grid(True, linestyle="--")
plt.title("Sales for Bathing Soap")

#command to save picture in downloads
plt.savefig("C:\\Users\\Yutika\\Desktop\\Semester-3 Prac and Skills\\Machine Learning 1\\BathingSoap.png", dpi=150)
plt.figure(figsize=(10,7))
plt.show()

# %%
print("The image stored in hard drive:")
from IPython.display import Image
Image(filename='saved_img.png')
# Out:
# The image stored in hard drive:

# %% [markdown]
# **Comment:-** Maximum units of _Bathing Soaps_ are sold in the 12th month (December) while the least number of units are sold in month no. 2 (February).

# %% [markdown]
# **Q7. Read the total profit of each month and show it using the histogram to see the most common profit ranges.**

# %%
profitList = df['total_profit'].tolist()
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(profitList, profit_range, label = 'Profit data')
plt.xlabel('profit range in dollar')
plt.ylabel('Actual Profit in dollar')
plt.legend(loc='upper left')
plt.xticks(profit_range)
plt.title('Profit data')
plt.show()

# %% [markdown]
# **Comment:-**  The most profitable range is between $ 250,000 to 350,000

# %% [markdown]
# **Q8. Calculate total sale data for last year for each product and show it using a Pie chart. Note: In Pie chart display Number of units sold per year for each product in percentage.**

# %%
fig = plt.figure(figsize=(7,7))
labels = ["Face Cream","Face Wash","Toothpaste","Bathing soap", "Shampoo","Moisturizer"]
sales_data = [df.facecream.sum(), df.facewash.sum(),df.toothpaste.sum(),df.bathingsoap.sum(),df.shampoo.sum(),df.moisturizer.sum()]
plt.axis=("equal")
plt.pie(sales_data,labels=labels,autopct = '%1.1f%%')
plt.legend(loc="lower right")
plt.figure(figsize=(10,10))
plt.show()

# %% [markdown]
# **Comment:-** Out of all the products considered for comparison in the pie-chart above, _Bathing Soap_ contributes close to 41% of the total sales all year round whereas _Facewash_ and _Moisturizer_ contribute only 6.6% of the total sales each.

# %% [markdown]
# **Q9. Read the sales of Bathing soap and facewash of all months and display it using the Subplot.**

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 10,7
monthList =df ['month_number'].tolist()
bathingsoap=df ['bathingsoap'].tolist()
faceWashSalesData=df ['facewash'].tolist()
f, axarr = plt.subplots(2,sharex=True)
axarr[0].plot(monthList, bathingsoap,label='Bathingsoap Sales Data',color='k',marker='o',linewidth=3)
axarr[0].set_title('Sales data of Bathingsoap')
axarr[1].plot(monthList, faceWashSalesData, label ='Face Wash Sales Data',color='r',marker='o',linewidth=3)
axarr[1].set_title('Sales data of facewash')
plt.xticks(monthList)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number',size=11)
plt.show()

# %% [markdown]
# **Comment:-** The pattern of units sold i.e. in _Bathing soap_ and _Facewash_ are pretty similar up until month no. 11 where sales of bathing soap goes up and facewash plummets.

# %% [markdown]
# **Q10. Read all product sales data and show it using the stack plot.**

# %%
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot([],[],color='m', label='face Cream', linewidth=5)
plt.plot([],[],color='c', label='Face wash', linewidth=5)
plt.plot([],[],color='r', label='Tooth paste', linewidth=5)
plt.plot([],[],color='k', label='Bathing soap', linewidth=5)
plt.plot([],[],color='g', label='Shampoo', linewidth=5)
plt.plot([],[],color='y', label='Moisturizer', linewidth=5)

plt.stackplot(monthList, faceCremSalesData, faceWashSalesData, toothPasteSalesData, 
              bathingsoapSalesData, shampooSalesData, moisturizerSalesData, 
              colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
plt.title('Alll product sales data using stack plot')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **Comment:-** From the plot above, one can make out that the sales of Bathing Soap in particular is higher as compared to the other products while the sales of Moisturizer is the least. Overall, the trend of sales observes a positive trend throughout the year with a only a few plumets.
